# %%
# show 10 random sentences in each of 50 clusters
# to see other scenarios, change 'wedding' to 'camping', 'travel new york', or 'travel paris', then hit CTRL+ENTER
# click the left panel to expand the cell

clusters, albums, sentences = cluster.visualize_clusters('wedding', opt.cluster)
# Out:
# feature_ubigram_10_method_kmeans_n_cluster_50
# clusters/initial/wedding/params_-max_iter_300_n_jobs_6_precompute_distances_True-_query_wedding_setting_-feature_ubigram_10_method_kmeans_n_cluster_50-
#     <div>
#     <p class="gallery_title">Cluster 7 (131981 captions)</p><br/>
#     <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm8.staticflickr.com/7203/6945659799_69d4e2f68e.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="after party at Wood House"
#     style="text-decoration:none;"><div class="ellipsis-module line-clamp">after party at Wood House</div></a>
#     </figcaption>
#
# </figure>
#
# </div>
# <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm4.staticflickr.com/3895/14969713107_af1800e927.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="Arriving at church"
# ...

# %%
uc = clusters.drop_duplicates('cluster')
uc[uc.cluster_size > 0]

album = albums[(albums.albid=='70475256@N00_2012-02-04T11:46:34')]
summary = album[(album.cluster!=7) & np.in1d(album.cluster.values, uc.cluster.values)][['url', 'cluster', 'sentences']]
summary = summary.drop_duplicates('cluster')
album['summary'] = False
album.loc[temp.index, 'summary'] = True

vis.display_gallery(album, highlights='summary')
# Out:
# -c:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/localdirs/jianchen/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#     <div>
#
#     <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm8.staticflickr.com/7050/6773781340_6d4706ac7b.jpg/>
# <div class="img_tag">7</div>
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="Kurt & Miwako"
# ...

# %%
clusters, albums, sentences = cluster.visualize_clusters('camping', opt.cluster)
# Out:
# feature_ubigram_10_method_kmeans_n_cluster_50
# clusters/initial/camping/params_-max_iter_300_n_jobs_6_precompute_distances_True-_query_camping_setting_-feature_ubigram_10_method_kmeans_n_cluster_50-
#     <div>
#     <p class="gallery_title">Cluster 31 (105435 captions)</p><br/>
#     <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm9.staticflickr.com/8434/7784150392_d3e5117d7e.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="Kyle Smith , Zone"
#     style="text-decoration:none;"><div class="ellipsis-module line-clamp">Kyle Smith , Zone</div></a>
#     </figcaption>
#
# </figure>
#
# </div>
# <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm9.staticflickr.com/8312/8067435202_80bf9696cd.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="Tree and Leaves"
#     style="text-decoration:none;"><div class="ellipsis-module line-clamp">Tree and Leaves</div></a>
# ...

# %%
clusters, albums, sentences = cluster.visualize_clusters('travel new york', opt.cluster)
# Out:
# feature_ubigram_10_method_kmeans_n_cluster_50
# clusters/initial/travel_new_york/params_-max_iter_300_n_jobs_6_precompute_distances_True-_query_travel_new_york_setting_-feature_ubigram_10_method_kmeans_n_cluster_50-
#     <div>
#     <p class="gallery_title">Cluster 6 (177611 captions)</p><br/>
#     <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm4.staticflickr.com/3164/2956474931_46ebd93503.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="Harlequin squash at Stuart 's Farm"
#     style="text-decoration:none;"><div class="ellipsis-module line-clamp">Harlequin squash at Stuart 's Farm</div></a>
#     </figcaption>
#
# </figure>
#
# </div>
# <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm4.staticflickr.com/3265/2588071263_26f743bf79.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="nice bathroom . This is in Marigot , the French capital of St. Martin"
# ...

# %%
clusters, albums, sentences = cluster.visualize_clusters('travel paris', opt.cluster)
# Out:
# feature_ubigram_10_method_kmeans_n_cluster_50
# clusters/initial/travel_paris/params_-max_iter_300_n_jobs_6_precompute_distances_True-_query_travel_paris_setting_-feature_ubigram_10_method_kmeans_n_cluster_50-
#     <div>
#     <p class="gallery_title">Cluster 1 (177796 captions)</p><br/>
#     <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm2.staticflickr.com/1151/866606199_4d4ffb63ce.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title=""
#     style="text-decoration:none;"><div class="ellipsis-module line-clamp"></div></a>
#     </figcaption>
#
# </figure>
#
# </div>
# <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm5.staticflickr.com/4056/4463447828_aa56fa442c.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title=""
#     style="text-decoration:none;"><div class="ellipsis-module line-clamp"></div></a>
#     </figcaption>
#
# </figure>
#
# </div>
# ...

# %%
cluster.display_clusters(clusters[clusters.sentences.str.contains('eiffel', case=False)])
# Out:
# /home/localdirs/jianchen/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:2798: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   inplace=inplace, kind=kind, na_position=na_position)
#     <div>
#     <p class="gallery_title">Cluster 1 (177796 captions)</p><br/>
#     <div class="gallery_cell">
# <figure>
#
# <div class="img_wrapper">
# <img src=http://farm4.staticflickr.com/3246/2593465125_101f80d06c.jpg/>
#
# </div>
#
# <figcaption><a href="#" class="href_ellipsis" title="Avenue Gustave Eiffel"
#     style="text-decoration:none;"><div class="ellipsis-module line-clamp">Avenue Gustave Eiffel</div></a>
#     </figcaption>
#
# </figure>
#
# </div>
#     </div>
#     <div>
#     <p class="gallery_title">Cluster 25 (9687 captions)</p><br/>
#     <div class="gallery_cell">
# <figure>
#
# ...
